# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamruzzaman2200/Ai/blob/main/Caesar_Cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Encryption**

# %%
def caesar_encrypt(plaintext, key):
    result = ""

    for char in plaintext:
        if char.isalpha():
            shift = key % 26
            if char.islower():
                result += chr((ord(char) - ord('a') + shift) % 26 + ord('a'))
            else:
                result += chr((ord(char) - ord('A') + shift) % 26 + ord('A'))
        else:
            result += char

    return result


# Taking input from user
text = input("Enter plaintext: ")
key = int(input("Enter key (shift): "))

encrypted_text = caesar_encrypt(text, key)
print("Encrypted text:", encrypted_text)
# Out:
# Enter plaintext: Hello World
# Enter key (shift): 23
# Encrypted text: Ebiil Tloia

# %% [markdown]
# # **Decryption**

# %%
def caesar_decrypt(ciphertext, key):
    result = ""

    for char in ciphertext:
        if char.isalpha():
            shift = key % 26
            if char.islower():
                result += chr((ord(char) - ord('a') - shift) % 26 + ord('a'))
            else:
                result += chr((ord(char) - ord('A') - shift) % 26 + ord('A'))
        else:
            result += char

    return result


# User input
cipher = input("Enter ciphertext: ")
key = int(input("Enter key (shift): "))

decrypted_text = caesar_decrypt(cipher, key)
print("Decrypted text:", decrypted_text)
# Out:
# Enter ciphertext: Ebiil Tloia
# Enter key (shift): 23
# Decrypted text: Hello World
