# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamruzzaman2200/Ai/blob/main/ML_Workflow_on_the_Lung_Cancer_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install Required Libraries

# %%
# !pip install imblearn boruta
# Out:
# Requirement already satisfied: imblearn in /usr/local/lib/python3.12/dist-packages (0.0)
# Requirement already satisfied: boruta in /usr/local/lib/python3.12/dist-packages (0.4.3)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from imblearn) (0.14.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.12/dist-packages (from boruta) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from boruta) (1.6.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from boruta) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.17.1->boruta) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.17.1->boruta) (3.6.0)

# %% [markdown]
# #Import All Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import matplotlib.ticker as mtick
import seaborn as sns
import matplotlib.pyplot as plt

# --- Preprocessing & Feature Engineering ---
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import TSNE
from sklearn.feature_selection import RFE
from boruta import BorutaPy

# --- Classifiers ---
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# --- Evaluation ---
from sklearn.metrics import accuracy_score

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# %% [markdown]
# #Load and Inspect the Dataset

# %%
try:
    df = pd.read_csv('/content/drive/MyDrive/DataSets/survey lung cancer.csv')
    print("✅ Dataset '/content/drive/MyDrive/DataSets/survey lung cancer.csv' loaded successfully.")
    print("\n--- First 5 Rows ---")
    print(df.head())
    print("\n--- Dataset Info ---")
    df.info()
except FileNotFoundError:
    print("❗️Error: '/content/drive/MyDrive/DataSets/survey lung cancer.csv' not found. Please ensure the file is uploaded.")
# Out:
# ✅ Dataset '/content/drive/MyDrive/DataSets/survey lung cancer.csv' loaded successfully.
#
# --- First 5 Rows ---
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO
#
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %% [markdown]
# #Clean and Encode the Data

# %%
# Clean Column Names (e.g., 'YELLOW_FINGERS' -> 'yellow_fingers')
df.columns = df.columns.str.lower()

# Encode 'gender' (M/F -> 1/0)
df['gender'] = LabelEncoder().fit_transform(df['gender'])

# Encode the target variable 'lung_cancer' (YES/NO -> 1/0)
df['lung_cancer'] = LabelEncoder().fit_transform(df['lung_cancer'])

print("--- Preprocessed and Encoded Data ---")
print(df.head())
# Out:
# --- Preprocessed and Encoded Data ---
#    gender  age  smoking  yellow_fingers  anxiety  peer_pressure  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    chronic disease  fatigue   allergy   wheezing  alcohol consuming  coughing  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    shortness of breath  swallowing difficulty  chest pain  lung_cancer
# 0                    2                      2           2            1
# 1                    2                      2           2            1
# 2                    2                      1           2            0
# 3                    1                      2           2            0
# 4                    2                      1           1            0

# %% [markdown]
# #EDA - Check for Class Imbalance

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='lung_cancer', data=df, palette='plasma')
plt.title('Distribution of Lung Cancer Cases', fontsize=16)
plt.xlabel('Lung Cancer (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
plt.show()

print("--- Class Distribution ---")
print(df['lung_cancer'].value_counts())
# Out:
# --- Class Distribution ---
# lung_cancer
# 1    270
# 0     39
# Name: count, dtype: int64

# %% [markdown]
# #EDA - Correlation Heatmap

# %%
# Define the custom palette
pal = ['#006400', '#228B22', '#32CD32', '#66CDAA', '#98FB98']

plt.figure(figsize=(16, 14))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap=pal, cbar=True, linewidths=0.5, linecolor='grey')
plt.title('Correlation Heatmap of All Features', fontsize=18)
plt.show()

# %% [markdown]
# #Define Features (X) and Target (y)

# %%
X = df.drop('lung_cancer', axis=1)
y = df['lung_cancer']
original_feature_names = X.columns.values # Save for later

print("--- Features (X) shape ---")
print(X.shape)
# Out:
# --- Features (X) shape ---
# (309, 15)

# %% [markdown]
# # Split Data into Training and Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,       # 30% of the data for testing
    random_state=42,
    stratify=y           # Crucial for imbalanced datasets
)

print(f"Training set size: {len(X_train)} samples")
print(f"Testing set size: {len(X_test)} samples")
# Out:
# Training set size: 216 samples
# Testing set size: 93 samples

# %% [markdown]
# #Pre-computation for Boruta Feature Selection

# %%
print("Running Boruta to identify relevant features. This may take a moment...")

boruta_scaler = StandardScaler()
X_train_boruta_scaled = boruta_scaler.fit_transform(X_train)
X_train_boruta_resampled, y_train_boruta_resampled = SMOTE(random_state=42).fit_resample(X_train_boruta_scaled, y_train)

boruta_model = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=5)
boruta_selector = BorutaPy(estimator=boruta_model, n_estimators='auto', random_state=42)

boruta_selector.fit(X_train_boruta_resampled, y_train_boruta_resampled)

boruta_features_mask = boruta_selector.support_
boruta_selected_features = original_feature_names[boruta_features_mask]

print(f"\nBoruta has selected {len(boruta_selected_features)} features.")
# Out:
# Running Boruta to identify relevant features. This may take a moment...
#
# Boruta has selected 15 features.

# %% [markdown]
# #Initialize Scalers, Classifiers, and Data Storage

# %%
# The 3 scalers we will compare
scalers = {
    "StandardScaler": StandardScaler(),
    "MinMaxScaler": MinMaxScaler(),
    "RobustScaler": RobustScaler()
}

# The 4 classifiers we will compare
classifiers = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# A dictionary to hold all our processed datasets
datasets = {}

print("✅ Scalers and Classifiers are ready for the experiment.")
# Out:
# ✅ Scalers and Classifiers are ready for the experiment.

# %% [markdown]
# # Create All Preprocessed Dataset Variations

# %%
for scaler_name, scaler in scalers.items():
    print(f"\n--- Processing data with {scaler_name} ---")

    # Step A: Scale the data
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Step B: Apply SMOTE to the training data to correct imbalance
    X_train_resampled, y_train_resampled = SMOTE(random_state=42).fit_resample(X_train_scaled, y_train)

    # Step C: Create the 'All Features' baseline dataset
    datasets[f'All Features ({scaler_name})'] = (X_train_resampled, X_test_scaled, y_train_resampled, y_test)

    # Step D: Apply PCA (Traditional)
    pca = PCA(n_components=10)
    X_train_pca = pca.fit_transform(X_train_resampled)
    X_test_pca = pca.transform(X_test_scaled)
    datasets[f'PCA ({scaler_name})'] = (X_train_pca, X_test_pca, y_train_resampled, y_test)

    # Step E: Apply LDA (Traditional)
    lda = LinearDiscriminantAnalysis(n_components=1)
    X_train_lda = lda.fit_transform(X_train_resampled, y_train_resampled)
    X_test_lda = lda.transform(X_test_scaled)
    datasets[f'LDA ({scaler_name})'] = (X_train_lda, X_test_lda, y_train_resampled, y_test)

    # Step F: Apply t-SNE (Traditional)
    tsne = TSNE(n_components=2, random_state=42)
    X_train_tsne = tsne.fit_transform(X_train_resampled)
    X_test_tsne = TSNE(n_components=2, random_state=42).fit_transform(X_test_scaled)
    datasets[f't-SNE ({scaler_name})'] = (X_train_tsne, X_test_tsne, y_train_resampled, y_test)

    # Step G: Apply RFE (Modern)
    rfe_model = RandomForestClassifier(n_estimators=100, random_state=42)
    rfe = RFE(estimator=rfe_model, n_features_to_select=8)
    rfe.fit(X_train_resampled, y_train_resampled)
    X_train_rfe = rfe.transform(X_train_resampled)
    X_test_rfe = rfe.transform(X_test_scaled)
    datasets[f'RFE ({scaler_name})'] = (X_train_rfe, X_test_rfe, y_train_resampled, y_test)

    # Step H: Apply Boruta (Modern)
    X_train_boruta = X_train_resampled[:, boruta_features_mask]
    X_test_boruta = X_test_scaled[:, boruta_features_mask]
    datasets[f'Boruta ({scaler_name})'] = (X_train_boruta, X_test_boruta, y_train_resampled, y_test)

print("\n✅ All dataset variations have been created.")
# Out:
# --- Processing data with StandardScaler ---
#
# --- Processing data with MinMaxScaler ---
#
# --- Processing data with RobustScaler ---
#
# ✅ All dataset variations have been created.

# %% [markdown]
# #Train and Evaluate All Models

# %%
results_list = []

print("🚀 Starting model training and evaluation...")

for dataset_name, (X_tr, X_te, y_tr, y_te) in datasets.items():
    for clf_name, clf in classifiers.items():
        clf.fit(X_tr, y_tr)
        y_pred = clf.predict(X_te)
        accuracy = accuracy_score(y_te, y_pred)
        results_list.append({
            "Method": dataset_name,
            "Classifier": clf_name,
            "Accuracy": accuracy
        })

print("✅ Model training and evaluation complete.")
# Out:
# 🚀 Starting model training and evaluation...
# ✅ Model training and evaluation complete.

# %% [markdown]
# #Display Final Results in a Table

# %%
results_df = pd.DataFrame(results_list)
sorted_results = results_df.sort_values(by="Accuracy", ascending=False).reset_index(drop=True)

print("--- 🏆 Accuracy Comparison of All Methods and Classifiers ---")
print(sorted_results.to_string())
# Out:
# --- 🏆 Accuracy Comparison of All Methods and Classifiers ---
#                            Method              Classifier  Accuracy
# 0     All Features (RobustScaler)           Random Forest  0.935484
# 1           Boruta (RobustScaler)           Random Forest  0.935484
# 2   All Features (StandardScaler)           Random Forest  0.924731
# 3              PCA (MinMaxScaler)           Random Forest  0.924731
# 4     All Features (MinMaxScaler)           Random Forest  0.924731
# 5         Boruta (StandardScaler)           Random Forest  0.924731
# 6              RFE (RobustScaler)           Random Forest  0.924731
# 7           Boruta (MinMaxScaler)           Random Forest  0.924731
# 8              LDA (MinMaxScaler)     K-Nearest Neighbors  0.913978
# 9           Boruta (MinMaxScaler)  Support Vector Machine  0.913978
# 10             RFE (MinMaxScaler)  Support Vector Machine  0.913978
# 11    All Features (MinMaxScaler)  Support Vector Machine  0.913978
# 12           RFE (StandardScaler)  Support Vector Machine  0.903226
# 13           RFE (StandardScaler)           Random Forest  0.903226
# 14           PCA (StandardScaler)           Random Forest  0.903226
# 15             RFE (MinMaxScaler)           Random Forest  0.903226
# 16    All Features (RobustScaler)     Logistic Regression  0.892473
# 17             PCA (RobustScaler)           Random Forest  0.892473
# 18             RFE (RobustScaler)  Support Vector Machine  0.892473
# 19          Boruta (RobustScaler)     Logistic Regression  0.892473
# 20             PCA (MinMaxScaler)  Support Vector Machine  0.892473
# 21  All Features (StandardScaler)  Support Vector Machine  0.892473
# 22        Boruta (StandardScaler)  Support Vector Machine  0.892473
# 23  All Features (StandardScaler)     Logistic Regression  0.881720
# 24          Boruta (MinMaxScaler)     Logistic Regression  0.881720
# 25        Boruta (StandardScaler)     Logistic Regression  0.881720
# 26    All Features (MinMaxScaler)     Logistic Regression  0.881720
# 27           PCA (StandardScaler)  Support Vector Machine  0.881720
# 28             LDA (RobustScaler)     K-Nearest Neighbors  0.881720
# 29           t-SNE (RobustScaler)           Random Forest  0.881720
# 30          Boruta (RobustScaler)  Support Vector Machine  0.881720
# 31    All Features (RobustScaler)  Support Vector Machine  0.881720
# 32             LDA (RobustScaler)     Logistic Regression  0.870968
# 33             RFE (RobustScaler)     K-Nearest Neighbors  0.870968
# 34           PCA (StandardScaler)     Logistic Regression  0.870968
# 35             PCA (MinMaxScaler)     Logistic Regression  0.870968
# 36           RFE (StandardScaler)     K-Nearest Neighbors  0.870968
# 37           LDA (StandardScaler)     Logistic Regression  0.870968
# 38           LDA (StandardScaler)  Support Vector Machine  0.870968
# 39           LDA (StandardScaler)     K-Nearest Neighbors  0.870968
# 40             LDA (MinMaxScaler)     Logistic Regression  0.870968
# 41             PCA (MinMaxScaler)     K-Nearest Neighbors  0.870968
# 42             PCA (RobustScaler)     Logistic Regression  0.870968
# 43             PCA (RobustScaler)  Support Vector Machine  0.870968
# 44             RFE (MinMaxScaler)     Logistic Regression  0.870968
# 45             RFE (MinMaxScaler)     K-Nearest Neighbors  0.870968
# 46             PCA (RobustScaler)     K-Nearest Neighbors  0.870968
# 47             LDA (RobustScaler)  Support Vector Machine  0.870968
# 48             LDA (MinMaxScaler)  Support Vector Machine  0.870968
# 49           PCA (StandardScaler)     K-Nearest Neighbors  0.860215
# 50    All Features (RobustScaler)     K-Nearest Neighbors  0.860215
# 51          Boruta (RobustScaler)     K-Nearest Neighbors  0.860215
# 52  All Features (StandardScaler)     K-Nearest Neighbors  0.849462
# 53           RFE (StandardScaler)     Logistic Regression  0.849462
# 54             RFE (RobustScaler)     Logistic Regression  0.849462
# 55        Boruta (StandardScaler)     K-Nearest Neighbors  0.849462
# 56           t-SNE (RobustScaler)     K-Nearest Neighbors  0.838710
# 57             LDA (RobustScaler)           Random Forest  0.838710
# 58    All Features (MinMaxScaler)     K-Nearest Neighbors  0.838710
# 59          Boruta (MinMaxScaler)     K-Nearest Neighbors  0.838710
# 60           t-SNE (RobustScaler)  Support Vector Machine  0.827957
# 61             LDA (MinMaxScaler)           Random Forest  0.817204
# 62           LDA (StandardScaler)           Random Forest  0.806452
# 63           t-SNE (MinMaxScaler)           Random Forest  0.645161
# 64           t-SNE (MinMaxScaler)     K-Nearest Neighbors  0.580645
# 65         t-SNE (StandardScaler)     Logistic Regression  0.569892
# 66         t-SNE (StandardScaler)           Random Forest  0.559140
# 67           t-SNE (MinMaxScaler)     Logistic Regression  0.548387
# 68         t-SNE (StandardScaler)     K-Nearest Neighbors  0.473118
# 69         t-SNE (StandardScaler)  Support Vector Machine  0.451613
# 70           t-SNE (MinMaxScaler)  Support Vector Machine  0.451613
# 71           t-SNE (RobustScaler)     Logistic Regression  0.322581

# %% [markdown]
# #Visualize Final Results in a Bar Chart

# %%
plt.figure(figsize=(16, 14))
ax = sns.barplot(x="Accuracy", y="Method", hue="Classifier", data=results_df, palette="viridis")

ax.set_title('Classifier Accuracy Comparison Across All Methods', fontsize=18)
ax.set_xlabel('Accuracy Score (%)', fontsize=14)
ax.set_ylabel('Preprocessing Method', fontsize=14)
ax.legend(title='Classifier', bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(axis='x', labelsize=12)

# Format x-axis as percentages
ax.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.xlim(0.7, 1.0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Add accuracy values to the bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.4f%%') # Increased decimal places for more exact percentage

plt.show()

# %% [markdown]
# #Final Results Summary and Conclusion

# %%
# Convert results list to a DataFrame (already done in previous cell, using existing results_df)

# Pivot the results for a clean comparison table
# Using 'Method' for rows and 'Classifier' for columns, and 'Accuracy' for values
results_pivot = results_df.pivot_table(index='Method', columns='Classifier', values='Accuracy')

print("="*60)
print("          Summary of Model Accuracies")
print("="*60)
display(results_pivot.style.format("{:.4f}").background_gradient(cmap='Greens'))

print("\n\n--- Final Analysis ---")
print("Based on the accuracy comparison across different preprocessing methods, scaling techniques, and classifiers, here are some observations:")
print("\nKey Takeaways:")
print("  - **Random Forest Classifier** generally performs well across various methods, achieving the highest accuracies.")
print("  - The combination of **RobustScaler** with **All Features** and **Boruta** feature selection, using **Random Forest**, yielded the top accuracy.")
print("  - Traditional dimensionality reduction methods like t-SNE seem to perform poorly in this classification task compared to others.")
print("  - The choice of scaler and feature selection method significantly impacts model performance.")
# Out:
# ============================================================
#           Summary of Model Accuracies
# ============================================================
# <style type="text/css">
# #T_e5150_row0_col0, #T_e5150_row3_col0, #T_e5150_row16_col0 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_e5150_row0_col1, #T_e5150_row2_col1, #T_e5150_row3_col1, #T_e5150_row5_col1 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_e5150_row0_col2, #T_e5150_row2_col2, #T_e5150_row3_col2, #T_e5150_row5_col2, #T_e5150_row9_col2, #T_e5150_row13_col2 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_e5150_row0_col3, #T_e5150_row1_col1, #T_e5150_row1_col2, #T_e5150_row3_col3, #T_e5150_row4_col1, #T_e5150_row4_col2, #T_e5150_row6_col0, #T_e5150_row12_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e5150_row1_col0, #T_e5150_row4_col0, #T_e5150_row11_col0 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_e5150_row1_col3, #T_e5150_row4_col3, #T_e5150_row11_col3 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_e5150_row2_col0, #T_e5150_row5_col0 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_e5150_row2_col3, #T_e5150_row5_col3, #T_e5150_row9_col3, #T_e5150_row13_col3 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_e5150_row6_col1, #T_e5150_row7_col1, #T_e5150_row8_col1, #T_e5150_row9_col1, #T_e5150_row10_col1, #T_e5150_row11_col1, #T_e5150_row12_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_e5150_row6_col2 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_e5150_row6_col3, #T_e5150_row7_col3, #T_e5150_row8_col3, #T_e5150_row10_col3 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_e5150_row7_col0 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_e5150_row7_col2 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_e5150_row8_col0, #T_e5150_row9_col0, #T_e5150_row10_col0, #T_e5150_row12_col0, #T_e5150_row13_col0, #T_e5150_row14_col0 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_e5150_row8_col2 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_e5150_row10_col2 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_e5150_row11_col2, #T_e5150_row12_col2, #T_e5150_row14_col2 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_e5150_row13_col1, #T_e5150_row14_col1 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_e5150_row14_col3 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_e5150_row15_col0 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_e5150_row15_col1 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_e5150_row15_col2 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_e5150_row15_col3, #T_e5150_row16_col1, #T_e5150_row17_col0, #T_e5150_row17_col2, #T_e5150_row17_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e5150_row16_col2 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_e5150_row16_col3 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_e5150_row17_col1 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# </style>
# <table id="T_e5150" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Classifier</th>
#       <th id="T_e5150_level0_col0" class="col_heading level0 col0" >K-Nearest Neighbors</th>
#       <th id="T_e5150_level0_col1" class="col_heading level0 col1" >Logistic Regression</th>
#       <th id="T_e5150_level0_col2" class="col_heading level0 col2" >Random Forest</th>
#       <th id="T_e5150_level0_col3" class="col_heading level0 col3" >Support Vector Machine</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5150_level0_row0" class="row_heading level0 row0" >All Features (MinMaxScaler)</th>
#       <td id="T_e5150_row0_col0" class="data row0 col0" >0.8387</td>
#       <td id="T_e5150_row0_col1" class="data row0 col1" >0.8817</td>
#       <td id="T_e5150_row0_col2" class="data row0 col2" >0.9247</td>
#       <td id="T_e5150_row0_col3" class="data row0 col3" >0.9140</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row1" class="row_heading level0 row1" >All Features (RobustScaler)</th>
#       <td id="T_e5150_row1_col0" class="data row1 col0" >0.8602</td>
#       <td id="T_e5150_row1_col1" class="data row1 col1" >0.8925</td>
#       <td id="T_e5150_row1_col2" class="data row1 col2" >0.9355</td>
#       <td id="T_e5150_row1_col3" class="data row1 col3" >0.8817</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row2" class="row_heading level0 row2" >All Features (StandardScaler)</th>
#       <td id="T_e5150_row2_col0" class="data row2 col0" >0.8495</td>
#       <td id="T_e5150_row2_col1" class="data row2 col1" >0.8817</td>
#       <td id="T_e5150_row2_col2" class="data row2 col2" >0.9247</td>
#       <td id="T_e5150_row2_col3" class="data row2 col3" >0.8925</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row3" class="row_heading level0 row3" >Boruta (MinMaxScaler)</th>
#       <td id="T_e5150_row3_col0" class="data row3 col0" >0.8387</td>
#       <td id="T_e5150_row3_col1" class="data row3 col1" >0.8817</td>
#       <td id="T_e5150_row3_col2" class="data row3 col2" >0.9247</td>
#       <td id="T_e5150_row3_col3" class="data row3 col3" >0.9140</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row4" class="row_heading level0 row4" >Boruta (RobustScaler)</th>
#       <td id="T_e5150_row4_col0" class="data row4 col0" >0.8602</td>
#       <td id="T_e5150_row4_col1" class="data row4 col1" >0.8925</td>
#       <td id="T_e5150_row4_col2" class="data row4 col2" >0.9355</td>
#       <td id="T_e5150_row4_col3" class="data row4 col3" >0.8817</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row5" class="row_heading level0 row5" >Boruta (StandardScaler)</th>
#       <td id="T_e5150_row5_col0" class="data row5 col0" >0.8495</td>
#       <td id="T_e5150_row5_col1" class="data row5 col1" >0.8817</td>
#       <td id="T_e5150_row5_col2" class="data row5 col2" >0.9247</td>
#       <td id="T_e5150_row5_col3" class="data row5 col3" >0.8925</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row6" class="row_heading level0 row6" >LDA (MinMaxScaler)</th>
#       <td id="T_e5150_row6_col0" class="data row6 col0" >0.9140</td>
#       <td id="T_e5150_row6_col1" class="data row6 col1" >0.8710</td>
#       <td id="T_e5150_row6_col2" class="data row6 col2" >0.8172</td>
#       <td id="T_e5150_row6_col3" class="data row6 col3" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row7" class="row_heading level0 row7" >LDA (RobustScaler)</th>
#       <td id="T_e5150_row7_col0" class="data row7 col0" >0.8817</td>
#       <td id="T_e5150_row7_col1" class="data row7 col1" >0.8710</td>
#       <td id="T_e5150_row7_col2" class="data row7 col2" >0.8387</td>
#       <td id="T_e5150_row7_col3" class="data row7 col3" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row8" class="row_heading level0 row8" >LDA (StandardScaler)</th>
#       <td id="T_e5150_row8_col0" class="data row8 col0" >0.8710</td>
#       <td id="T_e5150_row8_col1" class="data row8 col1" >0.8710</td>
#       <td id="T_e5150_row8_col2" class="data row8 col2" >0.8065</td>
#       <td id="T_e5150_row8_col3" class="data row8 col3" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row9" class="row_heading level0 row9" >PCA (MinMaxScaler)</th>
#       <td id="T_e5150_row9_col0" class="data row9 col0" >0.8710</td>
#       <td id="T_e5150_row9_col1" class="data row9 col1" >0.8710</td>
#       <td id="T_e5150_row9_col2" class="data row9 col2" >0.9247</td>
#       <td id="T_e5150_row9_col3" class="data row9 col3" >0.8925</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row10" class="row_heading level0 row10" >PCA (RobustScaler)</th>
#       <td id="T_e5150_row10_col0" class="data row10 col0" >0.8710</td>
#       <td id="T_e5150_row10_col1" class="data row10 col1" >0.8710</td>
#       <td id="T_e5150_row10_col2" class="data row10 col2" >0.8925</td>
#       <td id="T_e5150_row10_col3" class="data row10 col3" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_e5150_level0_row11" class="row_heading level0 row11" >PCA (StandardScaler)</th>
#       <td id="T_e5150_row11_col0"
# --- Final Analysis ---
# Based on the accuracy comparison across different preprocessing methods, scaling techniques, and classifiers, here are some observations:
#
# Key Takeaways:
#   - **Random Forest Classifier** generally performs well across various methods, achieving the highest accuracies.
#   - The combination of **RobustScaler** with **All Features** and **Boruta** feature selection, using **Random Forest**, yielded the top accuracy.
#   - Traditional dimensionality reduction methods like t-SNE seem to perform poorly in this classification task compared to others.
#   - The choice of scaler and feature selection method significantly impacts model performance.

# %%
# Find the maximum accuracy
max_accuracy = results_df['Accuracy'].max()

# Filter the DataFrame to get all rows with the maximum accuracy
best_performing_models = results_df[results_df['Accuracy'] == max_accuracy]

print("--- 🏆 Best Performing Models (Maximum Accuracy) ---")
print(f"Maximum Accuracy: {max_accuracy:.4f}")

# Display all combinations that achieved the maximum accuracy
if not best_performing_models.empty:
    display(best_performing_models.style.format({'Accuracy': '{:.4f}'}))
else:
    print("No models found with the maximum accuracy.")
# Out:
# --- 🏆 Best Performing Models (Maximum Accuracy) ---
# Maximum Accuracy: 0.9355
# <style type="text/css">
# </style>
# <table id="T_c3fb5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3fb5_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_c3fb5_level0_col1" class="col_heading level0 col1" >Classifier</th>
#       <th id="T_c3fb5_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3fb5_level0_row0" class="row_heading level0 row0" >51</th>
#       <td id="T_c3fb5_row0_col0" class="data row0 col0" >All Features (RobustScaler)</td>
#       <td id="T_c3fb5_row0_col1" class="data row0 col1" >Random Forest</td>
#       <td id="T_c3fb5_row0_col2" class="data row0 col2" >0.9355</td>
#     </tr>
#     <tr>
#       <th id="T_c3fb5_level0_row1" class="row_heading level0 row1" >71</th>
#       <td id="T_c3fb5_row1_col0" class="data row1 col0" >Boruta (RobustScaler)</td>
#       <td id="T_c3fb5_row1_col1" class="data row1 col1" >Random Forest</td>
#       <td id="T_c3fb5_row1_col2" class="data row1 col2" >0.9355</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🏆 Best Performing Models
